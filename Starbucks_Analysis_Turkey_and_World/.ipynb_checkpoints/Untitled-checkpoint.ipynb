# %% [markdown]
# # Importing Libraries

# %%
pip install basemap
# Out:
# Collecting basemap
#   Using cached basemap-1.3.4-cp39-cp39-win_amd64.whl (443 kB)
# Collecting pyproj<3.4.0,>=1.9.3
#   Using cached pyproj-3.3.1-cp39-cp39-win_amd64.whl (6.4 MB)
# Collecting basemap-data<1.4,>=1.3.2
#   Using cached basemap_data-1.3.2-py2.py3-none-any.whl (30.5 MB)
# Requirement already satisfied: matplotlib<3.6,>=1.5 in c:\users\yusuf\anaconda3\lib\site-packages (from basemap) (3.4.3)
# Collecting pyshp<2.4,>=1.2
#   Using cached pyshp-2.3.1-py2.py3-none-any.whl (46 kB)
# Collecting numpy<1.24,>=1.22
#   Downloading numpy-1.23.2-cp39-cp39-win_amd64.whl (14.7 MB)
# Requirement already satisfied: cycler>=0.10 in c:\users\yusuf\anaconda3\lib\site-packages (from matplotlib<3.6,>=1.5->basemap) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\yusuf\anaconda3\lib\site-packages (from matplotlib<3.6,>=1.5->basemap) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\yusuf\anaconda3\lib\site-packages (from matplotlib<3.6,>=1.5->basemap) (8.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\yusuf\anaconda3\lib\site-packages (from matplotlib<3.6,>=1.5->basemap) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\yusuf\anaconda3\lib\site-packages (from matplotlib<3.6,>=1.5->basemap) (3.0.4)
# Requirement already satisfied: six in c:\users\yusuf\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib<3.6,>=1.5->basemap) (1.16.0)
# Requirement already satisfied: certifi in c:\users\yusuf\anaconda3\lib\site-packages (from pyproj<3.4.0,>=1.9.3->basemap) (2021.10.8)
# Installing collected packages: numpy, pyshp, pyproj, basemap-data, basemap
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.20.3
#     Uninstalling numpy-1.20.3:
#       Successfully uninstalled numpy-1.20.3
# Successfully installed basemap-1.3.4 basemap-data-1.3.2 numpy-1.23.2 pyproj-3.3.1 pyshp-2.3.1
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# daal4py 2021.3.0 requires daal==2021.2.3, which is not installed.
# scipy 1.7.1 requires numpy<1.23.0,>=1.16.5, but you have numpy 1.23.2 which is incompatible.
# numba 0.54.1 requires numpy<1.21,>=1.17, but you have numpy 1.23.2 which is incompatible.

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import warnings
from mpl_toolkits.basemap import Basemap
# %matplotlib inline
sns.set(style="white", context="talk")
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.filterwarnings("ignore",category=plt.cbook.mplDeprecation)

# %% [markdown]
# # Data Information

# %% [markdown]
# Reading starbucks data

# %%
data=pd.read_csv("C:/Users/Yusuf/Desktop/Starbucks Analysis Turkey and World/Data/directory.csv")

# %% [markdown]
# head of data

# %%
data.head()
# Out:
#        Brand  Store Number        Store Name Ownership Type  \
# 0  Starbucks  47370-257954     Meritxell, 96       Licensed
# 1  Starbucks  22331-212325  Ajman Drive Thru       Licensed
# 2  Starbucks  47089-256771         Dana Mall       Licensed
# 3  Starbucks  22126-218024        Twofour 54       Licensed
# 4  Starbucks  17127-178586      Al Ain Tower       Licensed
#
#                     Street Address              City State/Province Country  \
# 0                Av. Meritxell, 96  Andorra la Vella              7      AD
# 1             1 Street 69, Al Jarf             Ajman             AJ      AE
# 2     Sheikh Khalifa Bin Zayed St.             Ajman             AJ      AE
# 3                  Al Salam Street         Abu Dhabi             AZ      AE
# 4  Khaldiya Area, Abu Dhabi Island         Abu Dhabi             AZ      AE
#
#   Postcode Phone Number                 Timezone  Longitude  Latitude
# 0    AD500    376818720  GMT+1:00 Europe/Andorra       1.53     42.51
# 1      NaN          NaN     GMT+04:00 Asia/Dubai      55.47     25.42
# 2      NaN          NaN     GMT+04:00 Asia/Dubai      55.47     25.39
# 3      NaN          NaN     GMT+04:00 Asia/Dubai      54.38     24.48
# 4      NaN          NaN     GMT+04:00 Asia/Dubai      54.54     24.51

# %%
data.shape
# Out:
# (25600, 13)

# %%
data.columns
# Out:
# Index(['Brand', 'Store Number', 'Store Name', 'Ownership Type',
#        'Street Address', 'City', 'State/Province', 'Country', 'Postcode',
#        'Phone Number', 'Timezone', 'Longitude', 'Latitude'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# Brand                0
# Store Number         0
# Store Name           0
# Ownership Type       0
# Street Address       2
# City                15
# State/Province       0
# Country              0
# Postcode          1522
# Phone Number      6861
# Timezone             0
# Longitude            1
# Latitude             1
# dtype: int64

# %% [markdown]
# # How many brands are available in the data?

# %%
x=data['Brand'].value_counts()
print(x)
plt.figure(figsize=(8, 6))
fig=sns.barplot(x.index,x.values)
plt.xlabel('Brands')
plt.ylabel('Density')
fig.set_title('Distribution of Brands')
# Out:
# Starbucks                25249
# Teavana                    348
# Evolution Fresh              2
# Coffee House Holdings        1
# Name: Brand, dtype: int64
# Text(0.5, 1.0, 'Distribution of Brands')

# %% [markdown]
# ### Which country does the 'Coffee House Holdings' brand use?

# %%
HouseC=data[data['Brand']=='Coffee House Holdings']['Country'].value_counts()
print(HouseC)
# Out:
# US    1
# Name: Country, dtype: int64

# %% [markdown]
# ### Which country does the 'Tevana' brand use?

# %%
TevanaC=data[data['Brand']=='Teavana']['Country'].value_counts()[:10]
print(TevanaC)
plt.figure(figsize=(8, 6))
fig=sns.barplot(TevanaC.index,TevanaC.values)
plt.xlabel('Country')
plt.ylabel('Density')
fig.set_title('Distribution of Tevana Brand')
# Out:
# US    294
# CA     53
# PR      1
# Name: Country, dtype: int64
# Text(0.5, 1.0, 'Distribution of Tevana Brand')

# %% [markdown]
# ### Which country does 'Starbucks' brand use?

# %%
Starbucks=data[data['Brand']=='Starbucks']['Country'].value_counts()[1:10]
print(Starbucks)
plt.figure(figsize=(8, 6))
fig=sns.barplot(Starbucks.index,Starbucks.values)
plt.xlabel('Country')
plt.ylabel('Density')
fig.set_title('Distribution of Starbucks Brand')
# Out:
# CN    2734
# CA    1415
# JP    1237
# KR     993
# GB     901
# MX     579
# TW     394
# TR     326
# PH     298
# Name: Country, dtype: int64
# Text(0.5, 1.0, 'Distribution of Starbucks Brand')

# %%
data['Store Name'].value_counts()[1:10]
# Out:
# SPA                      6
# مركز أوتاد               2
# Magnolia                 2
# Mabohai Shopping Mall    2
# Division del Norte       2
# Plaza America            2
# Lemessos Enaerios        2
# Yoido IFC Mall - 1F      2
# CentrO Ground Floor      2
# Name: Store Name, dtype: int64

# %% [markdown]
# # How many ownerships are available in the data?

# %%
OwnerShip=data['Ownership Type'].value_counts()
print(OwnerShip)
plt.figure(figsize=(8, 6))
fig=sns.barplot(OwnerShip.index,OwnerShip.values)
plt.xlabel('Ownership Type')
plt.ylabel('Density')
fig.set_title('Distribution of Ownership Type')
# Out:
# Company Owned    11932
# Licensed          9375
# Joint Venture     3976
# Franchise          317
# Name: Ownership Type, dtype: int64
# Text(0.5, 1.0, 'Distribution of Ownership Type')

# %% [markdown]
# ### Which country has Franchise ownership?

# %%
Franchise=data[data['Ownership Type']=='Franchise']['Country'].value_counts()
plt.figure(figsize=(8, 6))
Franchise.plot.pie(autopct="%.1f%%");

# %% [markdown]
# ### Which country has Joint Venture ownership?

# %%
JointVenture=data[data['Ownership Type']=='Joint Venture']['Country'].value_counts()
print(JointVenture)
plt.figure(figsize=(8, 6))
fig=sns.barplot(JointVenture.index,JointVenture.values)
plt.xlabel('Country')
plt.ylabel('Density')
fig.set_title('Distribution of JointVenture')
# Out:
# CN    1220
# JP    1070
# KR     993
# TW     394
# RU     107
# IN      88
# PL      53
# CZ      28
# HU      16
# MY       6
# AR       1
# Name: Country, dtype: int64
# Text(0.5, 1.0, 'Distribution of JointVenture')

# %% [markdown]
# ### Which country has Licensed ownership?

# %%
Licensed=data[data['Ownership Type']=='Licensed']['Country'].value_counts()
print('Total number of country is ', len(Licensed))
#Top ten countries
plt.figure(figsize=(8, 6))
fig=sns.barplot(Licensed.index[1:10],Licensed.values[1:10])
plt.xlabel('Country')
plt.ylabel('Density')
fig.set_title('Distribution of Licensed')
# Out:
# Total number of country is  64
# Text(0.5, 1.0, 'Distribution of Licensed')

# %% [markdown]
# ### Which country has Company Owned ownership?

# %%
CompanyOwned=data[data['Ownership Type']=='Company Owned']['Country'].value_counts()
print(CompanyOwned)
print('Total number of country is ', len(CompanyOwned))
#Top ten countries
plt.figure(figsize=(8, 6))
fig=sns.barplot(CompanyOwned.index[1:10],CompanyOwned.values[1:10])
plt.xlabel('Country')
plt.ylabel('Density')
fig.set_title('Distribution of Company Owned')
# Out:
# US    8226
# CN    1339
# CA    1097
# GB     347
# TH     289
# DE     142
# SG     130
# BR     102
# JP     101
# FR      74
# CH      57
# AT      17
# NL      10
# PR       1
# Name: Country, dtype: int64
# Total number of country is  14
# Text(0.5, 1.0, 'Distribution of Company Owned')

# %% [markdown]
# # How many cities are Starbucks stores available?

# %%
City=data['City'].value_counts()
print(City)
print('Total number of cities is',len(City))
plt.figure(figsize=(12,8))
fig=sns.barplot(City.index[:10],City.values[:10])
plt.xlabel('City')
plt.ylabel('Density')
fig.set_title('Distribution of City')
# Out:
# 上海市              542
# Seoul            243
# 北京市              234
# New York         232
# London           216
#                 ...
# Tepebasi           1
# Isparta            1
# Mersin (Icel)      1
# Mersin Icel        1
# Midrand            1
# Name: City, Length: 5469, dtype: int64
# Total number of cities is 5469
# Text(0.5, 1.0, 'Distribution of City')
# C:\Users\Yusuf\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 19978 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Yusuf\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 28023 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Yusuf\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 24066 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Yusuf\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 21271 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Yusuf\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 20140 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Yusuf\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 19978 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\Yusuf\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 28023 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\Yusuf\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 24066 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\Yusuf\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 21271 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\Yusuf\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 20140 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# It can be seen in the figure that Shanghai has the highest number of stores than other cities.

# %% [markdown]
# ### How many state or province are Starbucks stores available?

# %%
State=data['State/Province'].value_counts()
print(State)
print('Total number of states is',len(State))
plt.figure(figsize=(12,8))
fig=sns.barplot(State.index[:10],State.values[:10])
plt.xlabel('State')
plt.ylabel('Density')
fig.set_title('Distribution of State')
# Out:
# CA     2821
# TX     1042
# ENG     787
# WA      757
# 11      706
#        ...
# 60        1
# ICA       1
# CAJ       1
# D         1
# SA        1
# Name: State/Province, Length: 338, dtype: int64
# Total number of states is 338
# Text(0.5, 1.0, 'Distribution of State')

# %% [markdown]
# California state has the highest Starbucks store than other states

# %% [markdown]
# ### Timezone

# %%
Timezone=data['Timezone'].value_counts()
print(Timezone)
print('Total number of timezone is',len(Timezone))
plt.figure(figsize=(25,8))
fig=sns.barplot(Timezone.index[:5],Timezone.values[:5])
plt.xlabel('State')
plt.ylabel('Density')
fig.set_title('Top 10 Country Distribution of Timezone')
# Out:
# GMT-05:00 America/New_York       4889
# GMT-08:00 America/Los_Angeles    4194
# GMT-06:00 America/Chicago        2901
# GMT+08:00 Asia/Beijing           2731
# GMT+09:00 Asia/Tokyo             1237
#                                  ...
# GMT+1:00 Europe/Luxembourg          2
# GMT+4:00 Europe/Samara              1
# GMT+2:00 Asia/Jerusalem             1
# GMT+0:00 Atlantic/Canary            1
# GMT+1:00 Europe/Andorra             1
# Name: Timezone, Length: 101, dtype: int64
# Total number of timezone is 101
# Text(0.5, 1.0, 'Top 10 Country Distribution of Timezone')

# %% [markdown]
# # World Map of Starbucks Store

# %%
plt.figure(figsize=(16,16))
worldmap = Basemap(projection='mill', 
              llcrnrlat=-80,
              urcrnrlat=80,
              llcrnrlon=-180,  
              urcrnrlon=180, 
              resolution='l')
worldmap.drawcoastlines()
worldmap.drawcountries()
worldmap.drawmapboundary(fill_color='white')

# Load in Longitude and Latitude data
Longitude = data["Longitude"].astype(float)
Latitude = data["Latitude"].astype(float)
x, y = worldmap(list(Longitude), list(Latitude))
worldmap.plot(x, y,'bo',markersize =5,color="green" )
plt.title('The World Map of Starbucks Store')
plt.show()
# Out:
# C:\Users\Yusuf\AppData\Local\Temp/ipykernel_6888/3357653632.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "bo" (-> color='b'). The keyword argument will take precedence.
#   worldmap.plot(x, y,'bo',markersize =5,color="green" )

# %% [markdown]
# #  Specific Approximation for Turkey Country

# %%
TurkeyData=data[data['Country']=='TR']
TurkeyData.head()
# Out:
#            Brand  Store Number Store Name Ownership Type  \
# 11241  Starbucks   3165-143231  Starbucks       Licensed
# 11242  Starbucks   3030-142267  Starbucks       Licensed
# 11243  Starbucks   1942-139246  Starbucks       Licensed
# 11244  Starbucks   6130-149624  Starbucks       Licensed
# 11245  Starbucks  23681-232564  Starbucks       Licensed
#
#                                           Street Address   City  \
# 11241  Yeni Mah. Ogretmenler Bulv. M1 Merkez, Alisver...  Adana
# 11242  Kurtulus Mah. Ziya Pasa Bulv. Ali Sadi, Apt. N...  Adana
# 11243               Incirlik Ussu 10. Sencer Komutanligi  Adana
# 11244         Guzelyali Mah.Kenan Evren Bulv., No: 105/B  Adana
# 11245  Guzelyali Mah. Turgut Ozal Bulvari No:44, Cuku...  Adana
#
#       State/Province Country Postcode     Phone Number  \
# 11241              1      TR     1000      322 2710457
# 11242              1      TR     1130  0 322 457 94 95
# 11243              1      TR     1220              NaN
# 11244              1      TR     1170   0322 235 21 26
# 11245              1      TR     1170              NaN
#
#                      Timezone  Longitude  Latitude
# 11241  GMT+2:00 Asia/Istanbul      35.24     37.02
# 11242  GMT+2:00 Asia/Istanbul      35.32     37.00
# 11243  GMT+2:00 Asia/Istanbul      35.44     37.00
# 11244  GMT+2:00 Asia/Istanbul      35.30     37.05
# 11245  GMT+2:00 Asia/Istanbul      35.30     37.05

# %%
TurkeyData.shape
# Out:
# (326, 13)

# %%
TurkeyData.isnull().sum()
# Out:
# Brand               0
# Store Number        0
# Store Name          0
# Ownership Type      0
# Street Address      0
# City                0
# State/Province      0
# Country             0
# Postcode           22
# Phone Number      181
# Timezone            0
# Longitude           0
# Latitude            0
# dtype: int64

# %% [markdown]
# ### Brand

# %%
TurkeyData['Brand'].value_counts()
# Out:
# Starbucks    326
# Name: Brand, dtype: int64

# %% [markdown]
# Only starbucks brand are used in Turkey

# %% [markdown]
# ### Ownership Type

# %%
TurkeyData['Ownership Type'].value_counts()
# Out:
# Licensed    326
# Name: Ownership Type, dtype: int64

# %% [markdown]
# ### City

# %%
TurkeyCity=TurkeyData['City'].value_counts()
print('Total number of city is', len(TurkeyCity))
plt.figure(figsize=(14,9))
fig=sns.barplot(TurkeyCity.index[:10],TurkeyCity.values[:10])
plt.xlabel('Cities')
plt.ylabel('Density')
fig.set_title('Distribution of City')
# Out:
# Total number of city is 42
# Text(0.5, 1.0, 'Distribution of City')

# %% [markdown]
# ### State/Province

# %%
TurkeyProvince=TurkeyData['State/Province'].value_counts()
print('Total number of states is',len(TurkeyProvince))
plt.figure(figsize=(12,8))
fig=sns.barplot(TurkeyProvince.index[:10],TurkeyProvince.values[:10])
plt.xlabel('Number of Provinces')
plt.ylabel('Density')
fig.set_title('Distribution of Province')
# Out:
# Total number of states is 24
# Text(0.5, 1.0, 'Distribution of Province')

# %% [markdown]
# 34 number represents province number of Istanbul. Istanbul has the highest population in Turkey. Therefore, there are 160 starbucks store in this city. Also, Ankara and Izmir follow it.

# %% [markdown]
# ### Timezone

# %%
TurkeyTimezone=TurkeyData['Timezone'].value_counts()
print(TurkeyTimezone)
# Out:
# GMT+2:00 Asia/Istanbul      231
# GMT+2:00 Europe/Istanbul     88
# GMT+000000 Etc/GMT+2          7
# Name: Timezone, dtype: int64

# %% [markdown]
# ### GMT+2:00 Asia/Istanbul

# %%
TurkeyAsia=TurkeyData[TurkeyData['Timezone']=='GMT+2:00 Asia/Istanbul']['City'].value_counts()
plt.figure(figsize=(12,8))
fig=sns.barplot(TurkeyAsia.index[:10],TurkeyAsia.values[:10])
plt.xlabel('City')
plt.ylabel('Density')
fig.set_title('Distribution of GMT+2:00 Asia/Istanbul Timezone')
# Out:
# Text(0.5, 1.0, 'Distribution of GMT+2:00 Asia/Istanbul Timezone')

# %% [markdown]
# ### GMT+2:00 Europe/Istanbul

# %%
TurkeyEurope=TurkeyData[TurkeyData['Timezone']=='GMT+2:00 Europe/Istanbul']['City'].value_counts()
print(TurkeyEurope)
plt.figure(figsize=(12,8))
fig=sns.barplot(TurkeyAsia.index[:10],TurkeyAsia.values[:10])
plt.xlabel('City')
plt.ylabel('Density')
fig.set_title('Distribution of GMT+2:00 Europe/Istanbul Timezone')
# Out:
# Istanbul             80
# Istanbul - Avrupa     8
# Name: City, dtype: int64
# Text(0.5, 1.0, 'Distribution of GMT+2:00 Europe/Istanbul Timezone')

# %% [markdown]
# ### GMT+000000 Etc/GMT+2

# %%
TurkeyEtc=TurkeyData[TurkeyData['Timezone']=='GMT+000000 Etc/GMT+2']['City'].value_counts()
print(TurkeyEtc)
plt.figure(figsize=(12,8))
fig=sns.barplot(TurkeyEtc.index[:10],TurkeyEtc.values[:10])
plt.xlabel('City')
plt.ylabel('Density')
fig.set_title('Distribution of GMT+000000 Etc/GMT+ Timezone')
# Out:
# Antalya        6
# Mersin Icel    1
# Name: City, dtype: int64
# Text(0.5, 1.0, 'Distribution of GMT+000000 Etc/GMT+ Timezone')

# %% [markdown]
# ### Turkey Starbucks Map

# %%
plt.figure(figsize=(16,16))
map = Basemap(projection='stere', 
              lat_0=38, lon_0=37,
              llcrnrlon=25, 
              llcrnrlat=34, 
              urcrnrlon=50, 
              urcrnrlat=43,resolution='l',area_thresh=10000,rsphere=6371200.)
map.drawcoastlines()
map.drawcountries()
map.drawmapboundary(fill_color='white')

# Load in Longitude and Latitude data
Longitude = TurkeyData["Longitude"].astype(float)
Latitude = TurkeyData["Latitude"].astype(float)
x, y = map(list(Longitude), list(Latitude))
map.plot(x, y,'bo',markersize =7,color="red" )
plt.title('The Turkey Map of Starbucks Store')
plt.show()
# Out:
# C:\Users\Yusuf\AppData\Local\Temp/ipykernel_6888/1340789974.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "bo" (-> color='b'). The keyword argument will take precedence.
#   map.plot(x, y,'bo',markersize =7,color="red" )
